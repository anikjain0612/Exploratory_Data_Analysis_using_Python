# %% [markdown]
# # Experiment No. 3
# ## Name: Anik Jain
# ## PRN: 25070123178
# ## Batch: A-3
# ## Title: Study of list & various operations on it

# %%
## Python Lists
list = ['pune', 'mumbai', 'nagpur']
print(thislist)
# Out:
# ['pune', 'mumbai', 'nagpur']

# %%
# List Length
list = ['pune', 'mumbai', 'nagpur']
print(len(list))
# Out:
# 3

# %%
# A list with strings, integers and boolean values:
list = ["abc", 34, True, 40, "male"]
print(list)
# Out:
# ['abc', 34, True, 40, 'male']

# %%
# Access items
list = ["pune", "mumbai", "nagpur"]
print(list[0])
# Out:
# pune

# %%
# Reverse/Negative Indexing
list = ["pune", "mumbai", "nagpur"]
print(list[-3])
# Out:
# pune

# %%
#Slicing
list = ["pune", "mumbai", "nagpur", "satara", "solapur"]
print(list[1:])
# Out:
# ['mumbai', 'nagpur', 'satara', 'solapur']

# %%
#Slicing
list = ["pune", "mumbai", "nagpur", "satara", "solapur"]
print(list[-3:])
# Out:
# ['nagpur', 'satara', 'solapur']

# %%
# Change Item value
thislist = ["pune", "mumbai", "nagpur"]
thislist[1] = "satara"
print(thislist)
# Out:
# ['pune', 'satara', 'nagpur']

# %%
# Append Items
thislist = ["pune", "mumbai", "nagpur"]
thislist.append("satara")
print(thislist)
# Out:
# ['pune', 'mumbai', 'nagpur', 'satara']

# %%
# Insert list
thislist = ["pune", "mumbai", "nagpur"]
thislist.insert(1, "satara")
print(thislist)
# Out:
# ['pune', 'satara', 'mumbai', 'nagpur']

# %%
# Extend List
thislist = ["pune", "mumbai", "nagpur"]
tropical = ["satara", "solapur"]
thislist.extend(tropical)
print(thislist)
# Out:
# ['pune', 'mumbai', 'nagpur', 'satara', 'solapur']

# %%
# Searching Items
x="mumbai" in ["pune", "mumbai", "nagpur"]
print (x)
# Out:
# True

# %%
# Repition
thislist = ["Friday"]
print(thislist * 10)
# Out:
# ['Friday', 'Friday', 'Friday', 'Friday', 'Friday', 'Friday', 'Friday', 'Friday', 'Friday', 'Friday']

# %%
numbers = [10, 20, 30, 40, 50]
# Slicing examples
print("Elements from index 1 to 3: ", numbers[1:4])
print("First 3 elements: ", numbers[:3])
print("Elements from index 2 ownwards: ", numbers[2:])
print("All elements: ", numbers[:])
# Out:
# Elements from index 1 to 3:  [20, 30, 40]
# First 3 elements:  [10, 20, 30]
# Elements from index 2 ownwards:  [30, 40, 50]
# All elements:  [10, 20, 30, 40, 50]

# %%
marks = [78,85,90,66,88]
print("Max: ", max(marks))
print("Min: ", min(marks))
print("Sum of marks: ", sum(marks))
print("No. of students: ", len(marks))
marks.sort()
print("Ascending order: ", marks)
print("Average: ", sum(marks)/len(marks))
# Out:
# Max:  90
# Min:  66
# Sum of marks:  407
# No. of students:  5
# Ascending order:  [66, 78, 85, 88, 90]
# Average:  81.4

# %%
''' Grocery Shopping List
A user maintains a grocery list for monthly shopping tasks

Grocery = [Flour, Shampoo, Oil, Bread, Soap]
print("Grocery list created: ", Grocery)
# Out:
#   File "/tmp/ipython-input-1603081732.py", line 1
#     ''' Grocery Shopping List
#     ^
# SyntaxError: incomplete input

# %%
contacts = [Tony, Martin, Chris, Johnny]
print ("Contacts created: ", contact)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1667137494.py in <cell line: 0>()
# ----> 1 contacts = [Tony, Martin, Chris, Johnny]
#       2 print ("Contacts created: ", contact)
#
# NameError: name 'Tony' is not defined
